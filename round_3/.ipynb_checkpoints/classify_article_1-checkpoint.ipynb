# %% [markdown]
# # 모듈 import

# %%
import sys
import random
import pickle

import pandas as pd
import numpy as np
import json
from konlpy.tag import Twitter
from sklearn.externals import joblib
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfTransformer, TfidfVectorizer

from sklearn.naive_bayes import MultinomialNB , GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier
from sklearn.svm import SVC
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.svm import LinearSVC

from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %%
import json
import os
import random

import konlpy

#import elice_challenge as ec

# %% [markdown]
# # 파일 읽기

# %%
test_out_data = open('./data/test.output')
#test_out_data = test_out_data.read()
#3test_out_data = test_out_data.splitlines()

# %%
train_data = json.load(open('./data/train_data.json'))

test_data = json.load(open('./data/test.input.json'))

with open('./data/test.output') as fp:
    test_out = fp.read()
    test_out_data = test_out.splitlines()

grading_data = json.load(open('./data/grading.input.json'))

# %% [markdown]
# 파일이 제대로 읽혔는지 확인합니다.

# %%
print(len(train_data))
print(len(test_data))
print(len(test_out_data))
print(len(grading_data))
# Out:
# 76500
# 4500
# 4500
# 9000

# %%
test_out_data[:10]
# Out:
# ['연합뉴스', '뉴시스', 'MBN', '동아일보', '채널A', '오마이뉴스', 'YTN', 'JTBC', '동아일보', '파이낸셜뉴스']

# %%
train_df = pd.DataFrame(train_data)[['text','writing']]
test_df = pd.DataFrame(test_data)[['text']]
test_df['writing'] = test_out_data
grading_df = pd.DataFrame(grading_data)[['text']]

# %%
train_df.head()
# Out:
#                                                 text writing
# 0  [앵커]청와대 민정수석을 지냈던 우병우씨의 소재를 놓고 설왕설래가 한창입니다. 지난...    JTBC
# 1  [<언론사명>]새누리당 원내대표 경선을 하루 앞둔 2일 청와대는 사실상 ‘불개입’ ...    서울신문
# 2   = 박근혜 대통령이 7일 오후 서울 은평구 한국여성정책연구원에서 열린 2016년 ...     뉴시스
# 3  이재오 의원. 사진=이재오 의원 페이스북 캡처[<언론사명> ] 새누리당을 탈당한 이...   아시아경제
# 4  ]곽상도(사진)새누리당 대구 중남구 예비후보는 24일 보도자료를 통해 "새누리당이 ...   헤럴드경제

# %%
test_df.head()
# Out:
#                                                 text writing
# 0  日, 위안부지원금 송금완료…'소녀상 압박' 우려(cg)[<언론사명>tv 제공]\n\...    연합뉴스
# 1  새누리 "안보와 안전, 민생이 최우선" 더민주 "박 대통령이 먼저 변해야" 국민의당...     뉴시스
# 2  "사실과 다르다" 국민의당, '김수민 리베이트 의혹' 정면 반박국민의당 김수민/사진...     MBN
# 3  [<언론사명>]본보-r&r; 총선의 해 여론조사“신인 선택” 31%〉“현역” 24%...    동아일보
# 4  김종인 더민주 대표는 자신이 던진 담뱃불이 어떻게 번지는 지, 느긋하게 즐기는 모습...     채널A

# %%
grading_df.head()
# Out:
#                                                 text
# 0  4당 체제에도 청문회·국감·지방자치 합의 제도적 성과 14대 국회도 3대 정치개혁입...
# 1  눈감은 부산고검장\n    (부산=<언론사명>)  = 문무일 부산고검장이 11일 부...
# 2  [앵커] \n일본 규수 구마모토 지진으로 대규모 사상자가 발생하면서 정부가 신속대응...
# 3  박근혜 대통령이 총선을 하루 앞두고 '새로운 국회론'을 강력히 설파했다. 핵심 민생...
# 4  차은택 구속기소…특검 체제까지 사실상 '8부 능선' 넘어차은택/사진=<언론사명>'비...

# %% [markdown]
# # vectorize

# %%
X = train_df.text
y = train_df.writing

# %%
# np.random.seed(10)
# shuffle_indices = np.random.permutation(np.arange(len(train_df)))
# X = train_df.text[shuffle_indices[:67000]]
# y = train_df.writing[shuffle_indices[:67000]]

# test_X = train_df.text[shuffle_indices[67000:]]
# test_y = train_df.writing[shuffle_indices[67000:]]

# %%
# 처음엔 이걸로 # vectorize train using Tfid(bag of words)

twitter = Twitter()

def tokenize_pos(doc):
    return ['/'.join(t) for t in twitter.pos(doc, norm=True, stem=True)]

vectorizer =  TfidfVectorizer(tokenizer=tokenize_pos, ngram_range=(1,2), use_idf=False, smooth_idf=False)

X = vectorizer.fit_transform(X)

# %%
reduced_feature_list.shape
# Out:
# (1941228, 1)

# %%
X = X.map(tokenize_pos)

# %%
X[0]
# Out:
# ['[/Punctuation',
#  '앵커/Noun',
#  ']/Punctuation',
#  '청와대/Noun',
#  '민정/Noun',
#  '수석/Noun',
#  '을/Josa',
#  '지내다/Verb',
#  '우/Adverb',
#  '병/Noun',
#  '우씨/Noun',
#  '의/Josa',
#  '소재/Noun',
#  '를/Josa',
#  '설왕설래/Noun',
#  '가/Josa',
#  '한창/Noun',
#  '이다/Adjective',
#  './Punctuation',
#  '지난주/Noun',
#  '청문회/Noun',
#  '때/Noun',
#  '출석요구서/Noun',
#  '수령/Noun',
#  '을/Josa',
#  '거부/Noun',
#  '하다/Verb',
#  '나오다/Verb',
#  '않다/Verb',
#  './Punctuation',
#  '국회/Noun',
#  '는/Josa',
#  '오다/Verb',
#  '19/Number',
#  '일/Noun',
#  '5/Number',
#  '차/Noun',
#  '청문회/Noun',
#  '에/Josa',
#  '우씨/Noun',
#  '를/Josa',
#  '다시/Noun',
#  '부르다/Verb',
#  '했지만/Josa',
#  ',/Punctuation',
#  '그/Noun',
#  '의/Josa',
#  '소재/Noun',
#  '가/Josa',
#  '파악/Noun',
#  '되다/Verb',
#  '않다/Verb',
#  '하다/Verb',
#  ',/Punctuation',
#  '불가능하다/Adjective',
#  '일/Noun',
#  '이다/Adjective',
#  './Punctuation',
#  '일각/Noun',
#  '에선/Josa',
#  '그/Noun',
#  '에게/Josa',
#  '현상금/Noun',
#  '까지/Josa',
#  '거/Noun',
#  '는/Josa',
#  '상황/Noun',
#  '까지/Josa',
#  '벌어지다/Verb',
#  '있다/Adjective',
#  './Punctuation',
#  '오늘/Noun',
#  '(/Punctuation',
#  '12/Number',
#  '일/Noun',
#  ')/Punctuation',
#  '국회/Noun',
#  '발제/Noun',
#  '에선/Josa',
#  '이/Noun',
#  '문제/Noun',
#  '를/Josa',
#  '얘기/Noun',
#  '해보다/Verb',
#  '하다/Verb',
#  './Punctuation',
#  ']/Punctuation',
#  '네/Noun',
#  ',/Punctuation',
#  '그렇다/Adjective',
#  './Punctuation',
#  '지난주/Noun',
#  "'/Punctuation",
#  '최순실/Noun',
#  '국정/Noun',
#  '농단/Noun',
#  '청문회/Noun',
#  "'/Punctuation",
#  '에/Josa',
#  '우/Adverb',
#  '병/Noun',
#  '우씨/Noun',
#  '는/Josa',
#  '모습/Noun',
#  '을/Josa',
#  '드러내다/Verb',
#  '않다/Verb',
#  './Punctuation',
#  '다른/Noun',
#  '사람/Noun',
#  '들/Suffix',
#  '처럼/Josa',
#  '출석요구서/Noun',
#  '를/Josa',
#  '전달/Noun',
#  '받다/Verb',
#  '불/Noun',
#  '출석/Noun',
#  '사유/Noun',
#  '를/Josa',
#  '내다/Verb',
#  '것/Noun',
#  '도/Josa',
#  '아니다/Adjective',
#  ',/Punctuation',
#  '아예/Noun',
#  '잠적/Noun',
#  '을/Josa',
#  '해/Noun',
#  '버리다/Verb',
#  ',/Punctuation',
#  '요구/Noun',
#  '서/Josa',
#  '전달/Noun',
#  '조차/Josa',
#  '안/Noun',
#  '되다/Verb',
#  '상황/Noun',
#  '이다/Verb',
#  '겁니다/Verb',
#  './Punctuation',
#  '어떻다/Adjective',
#  '보다/Verb',
#  '질/Noun',
#  '이/Josa',
#  '가장/Noun',
#  '안/Noun',
#  '좋다/Adjective',
#  '상황/Noun',
#  '이라고/Josa',
#  '볼/Noun',
#  '수/Noun',
#  '있다/Adjective',
#  '거/Noun',
#  '죠/Josa',
#  './Punctuation',
#  '보다/Verb',
#  '못/Noun',
#  '한/Josa',
#  '몇몇/Noun',
#  '분들/Suffix',
#  '이/Josa',
#  '"/Punctuation',
#  '우병우/Noun',
#  '를/Josa',
#  '잡다/Verb',
#  '"/Punctuation',
#  '고/Noun',
#  '하다/Verb',
#  '현상금/Noun',
#  '을/Josa',
#  '걸다/Verb',
#  './Punctuation',
#  '정봉주/Noun',
#  '전/Noun',
#  '의원/Noun',
#  ',/Punctuation',
#  '안민석/Noun',
#  '의원/Noun',
#  '이/Josa',
#  '각각/Noun',
#  '500/Number',
#  '만원/Noun',
#  ',/Punctuation',
#  '김성태/Noun',
#  "'/Punctuation",
#  '최순실/Noun',
#  '국정조사/Noun',
#  '특위/Noun',
#  '위원장/Noun',
#  "'/Punctuation",
#  '이/Noun',
#  '100/Number',
#  '만원/Noun',
#  ',/Punctuation',
#  '또/Noun',
#  '주진우/Noun',
#  '가다/Verb',
#  '200/Number',
#  '만원/Noun',
#  ',/Punctuation',
#  '이렇게/Adverb',
#  '도합/Noun',
#  '1300/Number',
#  '만원/Noun',
#  '이/Josa',
#  '걸리다/Verb',
#  '겁니다/Verb',
#  './Punctuation',
#  '심지어/Noun',
#  '는/Josa',
#  '많다/Adjective',
#  '시민/Noun',
#  '들/Suffix',
#  '이/Josa',
#  "'/Punctuation",
#  '나다/Verb',
#  '동참/Noun',
#  '하고/Josa',
#  '싶다/Verb',
#  "'/Punctuation",
#  '면서/Noun',
#  '계좌/Noun',
#  '를/Josa',
#  '열다/Verb',
#  '!/Punctuation',
#  '하다/Verb',
#  './Punctuation',
#  '그래서/Adverb',
#  '일종/Noun',
#  '의/Josa',
#  "'/Punctuation",
#  '펀딩/Noun',
#  "'/Punctuation",
#  '형식/Noun',
#  '으로/Josa',
#  '액수/Noun',
#  '가/Josa',
#  '계속/Noun',
#  '불어/Noun',
#  '날/Noun',
#  '것/Noun',
#  '같다/Adjective',
#  '하다/Verb',
#  './Punctuation',
#  '다른/Noun',
#  '분/Noun',
#  '들/Suffix',
#  '은/Josa',
#  '그렇다/Adjective',
#  '줄/Noun',
#  '알다/Verb',
#  ',/Punctuation',
#  '안민석/Noun',
#  '의원/Noun',
#  '이/Josa',
#  '500/Number',
#  '만원/Noun',
#  '을/Josa',
#  '걸다/Verb',
#  ',/Punctuation',
#  '이/Determiner',
#  '것/Noun',
#  '은/Josa',
#  '좀/Noun',
#  '충격/Noun',
#  '적다/Verb',
#  './Punctuation',
#  '저번/Noun',
#  '에/Josa',
#  '소개/Noun',
#  '해드리다/Verb',
#  ',/Punctuation',
#  '장/Noun',
#  '시호/Noun',
#  '잡다/Verb',
#  '저/Noun',
#  '랑/Josa',
#  '같이/Josa',
#  '야/Exclamation',
#  '밤/Noun',
#  '에/Josa',
#  '여기저기/Noun',
#  '돌아다니다/Verb',
#  '때/Noun',
#  ',/Punctuation',
#  '배/Noun',
#  '가/Josa',
#  '너무/Noun',
#  '고프다/Adjective',
#  ',/Punctuation',
#  '같이/Josa',
#  '24/Number',
#  '시간/Noun',
#  '하다/Verb',
#  '식당/Noun',
#  '가다/Verb',
#  '떡/Noun',
#  '만둣국/Noun',
#  '을/Josa',
#  '먹다/Verb',
#  './Punctuation',
#  '자다/Verb',
#  '먹다/Verb',
#  '나서다/Verb',
#  '계산/Noun',
#  '하다/Verb',
#  '하다/Verb',
#  ',/Punctuation',
#  '갑자기/Noun',
#  '"/Punctuation',
#  '지갑/Noun',
#  '을/Josa',
#  '차/Noun',
#  '에/Josa',
#  '두다/Verb',
#  '오다/Verb',
#  '"/Punctuation',
#  '고/Noun',
#  '하다/Verb',
#  '겁니다/Verb',
#  './Punctuation',
#  '이/Determiner',
#  '날/Noun',
#  '밥값/Noun',
#  '을/Josa',
#  '제/Noun',
#  '가/Josa',
#  '내다/Verb',
#  './Punctuation',
#  '아직/Noun',
#  '영수증/Noun',
#  '도/Josa',
#  '갖다/Verb',
#  '있다/Adjective',
#  './Punctuation',
#  '그러셨던/Noun',
#  '분/Noun',
#  '이/Josa',
#  '500/Number',
#  '만원/Noun',
#  '을/Josa',
#  '걸다/Verb',
#  './Punctuation',
#  '자/Noun',
#  ',/Punctuation',
#  '아무튼/Adverb',
#  '제/Noun',
#  '가/Josa',
#  '현상금/Noun',
#  '을/Josa',
#  '맨/Noun',
#  '처음/Noun',
#  '제안/Noun',
#  '하다/Verb',
#  '정봉주/Noun',
#  '전/Noun',
#  '의원/Noun',
#  '에게/Josa',
#  '전화/Noun',
#  '해봤다/Verb',
#  './Punctuation',
#  '뭔가/Noun',
#  '그럴듯하다/Adjective',
#  '제보/Noun',
#  '가/Josa',
#  '들어오다/Verb',
#  '말/Noun',
#  '이/Suffix',
#  '죠/Josa',
#  './Punctuation',
#  '그랬더니/Conjunction',
#  '이렇게/Adverb',
#  '말/Noun',
#  '하다/Verb',
#  '.[/Punctuation',
#  '정봉주/Noun',
#  '//Punctuation',
#  '전/Noun',
#  '의원/Noun',
#  ':/Punctuation',
#  '종로구/Noun',
#  '옥인동/Noun',
#  '소재/Noun',
#  '에/Josa',
#  '우/Adverb',
#  '병/Noun',
#  '우/Adverb',
#  '닮다/Verb',
#  '사람/Noun',
#  '이/Josa',
#  '마당/Noun',
#  '에서/Josa',
#  '서성/Noun',
#  '인/Josa',
#  '달다/Verb',
#  '걸/Noun',
#  '건물/Noun',
#  '에서/Josa',
#  '보다/Verb',
#  '사람/Noun',
#  '의/Josa',
#  '제보/Noun',
#  '가/Josa',
#  '하나/Noun',
#  '들어오다/Verb',
#  './Punctuation',
#  '그리고/Conjunction',
#  '이제/Noun',
#  '지금/Noun',
#  ',/Punctuation',
#  '방금/Noun',
#  '전/Noun',
#  '에는/Josa',
#  '강원도/Noun',
#  '모처/Noun',
#  ',/Punctuation',
#  '별장/Noun',
#  '으로/Josa',
#  '가다/Verb',
#  '(/Punctuation',
#  '늘다/Verb',
#  '제보/Noun',
#  '가/Josa',
#  '오다/Verb',
#  '.]/Punctuation',
#  '우/Adverb',
#  '병/Noun',
#  '우씨/Noun',
#  '를/Josa',
#  '잡다/Verb',
#  '것/Noun',
#  '만큼이나/Josa',
#  '중요하다/Adjective',
#  '건/Noun',
#  ',/Punctuation',
#  '이/Noun',
#  '돈/Noun',
#  '을/Josa',
#  '진짜/Noun',
#  '낼/Noun',
#  '거인/Noun',
#  '지/Josa',
#  '아니다/Adjective',
#  './Punctuation',
#  '정봉주/Noun',
#  '전/Noun',
#  '의원/Noun',
#  '은/Josa',
#  '요즘/Noun',
#  '개인/Noun',
#  '사업/Noun',
#  '을/Josa',
#  '하다/Verb',
#  '충분하다/Adjective',
#  '그렇다/Adjective',
#  '역량/Noun',
#  '이/Josa',
#  '되다/Verb',
#  '거/Noun',
#  '로/Josa',
#  '알/Noun',
#  '고/Josa',
#  '있다/Adjective',
#  ',/Punctuation',
#  '10/Number',
#  '살이/Noun',
#  '나/Josa',
#  '에게/Josa',
#  '밥/Noun',
#  '을/Josa',
#  '얻어먹다/Verb',
#  '하다/Verb',
#  '안민석/Noun',
#  '의원/Noun',
#  '은/Josa',
#  '과연/Noun',
#  '그렇다/Adjective',
#  '싶다/Verb',
#  '말/Noun',
#  '이/Suffix',
#  '죠/Josa',
#  '.[/Punctuation',
#  '정봉주/Noun',
#  '//Punctuation',
#  '전/Noun',
#  '의원/Noun',
#  ':/Punctuation',
#  '(/Punctuation',
#  '원래/Noun',
#  '는/Josa',
#  '자다/Verb',
#  '안내/Noun',
#  '는/Josa',
#  '분/Noun',
#  '인데/Josa',
#  ')/Punctuation',
#  '국민/Noun',
#  '적/Suffix',
#  '관심/Noun',
#  '이/Josa',
#  '집중/Noun',
#  '되다/Verb',
#  '있다/Adjective',
#  '문제/Noun',
#  '이기/Noun',
#  '때문/Noun',
#  '에/Josa',
#  '안민석/Noun',
#  '의원/Noun',
#  '이/Josa',
#  '만약/Noun',
#  '안내면/Noun',
#  '정치/Noun',
#  '적/Suffix',
#  '으로/Josa',
#  '매장/Noun',
#  '되다/Verb',
#  '않다/Verb',
#  '?/Punctuation',
#  '반드시/Noun',
#  '내다/Verb',
#  '.]/Punctuation',
#  '자/Noun',
#  ',/Punctuation',
#  '시청자/Noun',
#  '여러분/Noun',
#  '안심/Noun',
#  '하다/Verb',
#  './Punctuation',
#  '돈/Noun',
#  '은/Josa',
#  '확보/Noun',
#  '되다/Verb',
#  '것/Noun',
#  '같다/Adjective',
#  './Punctuation',
#  '이제/Noun',
#  '남다/Verb',
#  '일/Noun',
#  '은/Josa',
#  '우/Adverb',
#  '병/Noun',
#  '우씨/Noun',
#  '잡다/Verb',
#  '일만/Noun',
#  '남다/Verb',
#  './Punctuation',
#  '우/Adverb',
#  '병/Noun',
#  '우/Adverb',
#  '씨/Noun',
#  '가/Josa',
#  '밝히다/Verb',
#  '야하다/Adjective',
#  '내용/Noun',
#  '정말/Noun',
#  '많다/Adjective',
#  './Punctuation',
#  '온/Noun',
#  '세상/Noun',
#  '이/Josa',
#  '자기/Noun',
#  '를/Josa',
#  '잡다/Verb',
#  '저러다/Verb',
#  ',/Punctuation',
#  '맨/Noun',
#  '얼굴/Noun',
#  '로/Josa',
#  '돌아다니다/Verb',
#  '사람/Noun',
#  '없다/Adjective',
#  './Punctuation',
#  '분명/Noun',
#  '변장/Noun',
#  '을/Josa',
#  '하다/Verb',
#  '다니다/Verb',
#  '게/Noun',
#  '뻔하다/Adjective',
#  './Punctuation',
#  '그래서/Adverb',
#  '몽타주/Noun',
#  '를/Josa',
#  '소개/Noun',
#  '해드리다/Verb',
#  './Punctuation',
#  '똑똑하다/Adjective',
#  '봐/Noun',
#  '두다/Verb',
#  './Punctuation',
#  '일반/Noun',
#  '모자/Noun',
#  ',/Punctuation',
#  '그리고/Conjunction',
#  '벙거지/Noun',
#  '모자/Noun',
#  '를/Josa',
#  '쓸다/Verb',
#  '우/Adverb',
#  '병/Noun',
#  '우/Adverb',
#  '씨/Noun',
#  '이다/Adjective',
#  './Punctuation',
#  '선글라스/Noun',
#  '를/Josa',
#  '끼다/Verb',
#  '모습/Noun',
#  '도/Josa',
#  '나오다/Verb',
#  './Punctuation',
#  '벙거지/Noun',
#  '모자/Noun',
#  '를/Josa',
#  '쓰다/Verb',
#  '선/Noun',
#  '.../Punctuation']

# %% [markdown]
# ### tokenaize 결과 저장

# %%
#token_result = X.to_csv('token_result.csv', mode='w')

# %%
#X = pd.read_csv('token_result.csv', header=None, index_col= 0, names=['pos'] )

# %% [markdown]
# ### stopwords 만들기

# %%
# 조사와, 구두점 제거
results = ''
for i in range(len(X)):
    row = pd.Series(X[i])
    row = row[row.map(lambda x : True if 'Josa' in x or 
                             'Punctuation' in x
                          else False)].values
    results += str(', '.join(list(set(row))))

stopwords = set(results.split(', '))

# %%
stw
# Out:
# ['라오/Josa',
#  ']]"/Punctuation',
#  '마다/Josa',
#  '----/Punctuation',
#  ':>/Punctuation',
#  ')""/Punctuation',
#  '..."[/Punctuation',
#  '"</Punctuation',
#  '부터는/Josa',
#  '로는/Josa에/Josa',
#  ')+++[/Punctuation',
#  '대로의/Josa</Punctuation',
#  '!</Punctuation',
#  '고/Josa>/Punctuation',
#  '로다/Josa',
#  '부터/Josa에/Josa',
#  '네/Josa에/Josa',
#  '------------------------------------------/Punctuation',
#  '했지만/Josa에는/Josa',
#  '>]-/Punctuation',
#  "?'./Punctuation",
#  ')!"/Punctuation',
#  '.+/Punctuation</Punctuation',
#  ':</Punctuation',
#  '했지만/Josa]/Punctuation',
#  '난/Josa까지로/Josa',
#  ']."/Punctuation',
#  '??[/Punctuation',
#  '고/Josa',
#  '?/Punctuation마다/Josa',
#  '으로써/Josa</Punctuation',
#  '하고도/Josa',
#  '":/Punctuation',
#  '?]/Punctuation인데/Josa',
#  '**********)"/Punctuation',
#  '-(/Punctuation',
#  '조차/Josa에/Josa',
#  '?)(/Punctuation',
#  '롭고/Josa에/Josa',
#  '은/Josa에/Josa',
#  '에서/Josa',
#  '------------------------------------------------------------------------------------------------(/Punctuation',
#  '이라고/Josa라도/Josa',
#  '(./Punctuation',
#  ').)/Punctuation',
#  '보다/Josa에는/Josa',
#  '.."/Punctuation</Punctuation',
#  ';/Punctuation>/Punctuation',
#  '..."[</Punctuation',
#  '*****/Punctuation',
#  '토록/Josa',
#  '(?~/Punctuation',
#  "'(/Punctuation에서/Josa",
#  "?''[</Punctuation",
#  '께서/Josa밖에도/Josa',
#  '는/Josa',
#  '?-/Punctuation',
#  '...[/Punctuation',
#  '이라고/Josa까지로/Josa',
#  "?')'/Punctuation",
#  '),/Punctuation에/Josa',
#  '의/Josa',
#  '엔/Josa>]/Punctuation',
#  '까지와/Josa',
#  '!!!/Punctuation)/Punctuation',
#  '="/Punctuation',
#  '"*/Punctuation',
#  ',/Punctuation.../Punctuation',
#  '!),/Punctuation',
#  ',/Punctuation',
#  '.."/Punctuation에/Josa',
#  '.#/Punctuation',
#  '!./Punctuation',
#  '여/Josa라도/Josa',
#  '인/Josa</Punctuation',
#  '에를/Josa>/Punctuation',
#  ',/Punctuation까지로/Josa',
#  '보다/Josa에서/Josa',
#  "'>(/Punctuation",
#  '>)</Punctuation',
#  '보다/Josa로/Josa',
#  '?]/Punctuation에서/Josa',
#  '(+/Punctuation>/Punctuation',
#  '..,/Punctuation',
#  '%~/Punctuation',
#  '한/Josa로/Josa',
#  '고/Josa에서/Josa',
#  '으로부터의/Josa</Punctuation',
#  '가/Josa</Punctuation',
#  '.."</Punctuation',
#  '?"</Punctuation',
#  '에서만큼/Josa',
#  '`,/Punctuation',
#  '에도/Josa',
#  '게/Josa',
#  '이/Josa에서/Josa',
#  '만이/Josa에서/Josa',
#  '---------------------------------/Punctuation',
#  '..?(/Punctuation',
#  '.+++++/Punctuation',
#  '보다는/Josa',
#  '."-\'(/Punctuation',
#  '했지만/Josa마다/Josa',
#  '으로부터만/Josa',
#  '이라고도/Josa',
#  '.(<</Punctuation',
#  "']/Punctuation>/Punctuation",
#  ')-</Punctuation',
#  '!.../Punctuation',
#  '로운/Josa)/Punctuation',
#  '?~^^/Punctuation',
#  '까지야/Josa',
#  '조차도/Josa에/Josa',
#  "'(=/Punctuation",
#  '>][</Punctuation',
#  '만으로도/Josa라도/Josa',
#  '했지만/Josa에/Josa',
#  '했지만/Josa에서부터/Josa',
#  '하고는/Josa</Punctuation',
#  '만은/Josa',
#  '","/Punctuation',
#  '~,/Punctuation',
#  '.~/Punctuation',
#  "']/Punctuation에서/Josa",
#  '이자나/Josa',
#  '으로도/Josa)/Punctuation',
#  '이라곤/Josa',
#  '말고는/Josa',
#  '이라기보다는/Josa',
#  '....../Punctuation에/Josa',
#  ').][/Punctuation',
#  '>//Punctuation',
#  '이라고/Josa에서/Josa',
#  '했지만/Josa인데/Josa',
#  '}=/Punctuation',
#  ')][/Punctuation',
#  "'[/Punctuation",
#  '."(/Punctuation',
#  '이에요/Josa',
#  '%)?/Punctuation',
#  '?!/Punctuation',
#  '(//Punctuation',
#  '로운/Josa에/Josa',
#  '이라고/Josa에/Josa',
#  '으로선/Josa에서/Josa',
#  '에게도/Josa',
#  '?[</Punctuation',
#  ')#./Punctuation',
#  '는/Josa>/Punctuation',
#  '?,/Punctuation',
#  '...."/Punctuation',
#  '?!]/Punctuation',
#  '여/Josa>/Punctuation',
#  '):/Punctuation',
#  '이니/Josa',
#  '에서든지/Josa',
#  '""\'/Punctuation',
#  '엔/Josa',
#  '같이/Josa에서/Josa',
#  '%./Punctuation',
#  '"(</Punctuation',
#  '야말로/Josa',
#  '이라고/Josa이지만/Josa',
#  '>)"/Punctuation',
#  '.../Punctuation',
#  '~^^/Punctuation',
#  "'./Punctuation",
#  '스런/Josa',
#  '이든/Josa',
#  '*************)/Punctuation',
#  '+++</Punctuation',
#  '"..."[</Punctuation',
#  '?/Punctuation인데/Josa',
#  ',)/Punctuation',
#  '?>(/Punctuation',
#  ':/Punctuation에/Josa',
#  '!!!/Punctuation>/Punctuation',
#  '.(/Punctuation',
#  ">'/Punctuation</Punctuation",
#  '"#/Punctuation에/Josa',
#  '대로/Josa</Punctuation',
#  '같이/Josa]/Punctuation',
#  '***/Punctuation',
#  '#/Punctuation',
#  '&,/Punctuation',
#  '니까/Josa</Punctuation',
#  "...'/Punctuation",
#  '(#)/Punctuation',
#  '보다/Josa도/Josa',
#  '이라야/Josa',
#  '.-"/Punctuation',
#  '".../Punctuation>/Punctuation',
#  '?./Punctuation에/Josa',
#  ',[/Punctuation',
#  '이라/Josa하고/Josa',
#  '?/Punctuation에서/Josa',
#  '!!!/Punctuation에/Josa',
#  ')](/Punctuation',
#  '......."/Punctuation',
#  '으로나/Josa',
#  '>?</Punctuation',
#  '?#./Punctuation',
#  '."/Punctuation',
#  '네/Josa)/Punctuation',
#  '.}[/Punctuation',
#  '으로서는/Josa',
#  ']./Punctuation',
#  "'[</Punctuation>/Punctuation",
#  '에서처럼/Josa',
#  "%)',/Punctuation",
#  '밖엔/Josa',
#  '이야/Josa에/Josa',
#  ',/Punctuation와는/Josa',
#  '죠/Josa',
#  '%</Punctuation',
#  '.=/Punctuation',
#  '은/Josa>/Punctuation',
#  '이/Josa라도/Josa',
#  ")'(/Punctuation",
#  '<[/Punctuation',
#  '"(\'/Punctuation',
#  '했지만/Josa을/Josa',
#  '이니/Josa</Punctuation',
#  "'?[/Punctuation",
#  '?)/Punctuation',
#  '여서/Josa',
#  '****),/Punctuation',
#  '=</Punctuation',
#  '보다/Josa라도/Josa',
#  ':[/Punctuation',
#  '보다/Josa>/Punctuation',
#  '보다/Josa이고/Josa',
#  ')"</Punctuation',
#  '.)(/Punctuation',
#  '":"/Punctuation',
#  '?"\'/Punctuation',
#  '([</Punctuation에/Josa',
#  "',/Punctuation",
#  './/Punctuation</Punctuation',
#  '으로부터/Josa마다/Josa',
#  '에요/Josa</Punctuation',
#  '같이/Josa에/Josa',
#  '~?/Punctuation',
#  '??(/Punctuation',
#  '~?"/Punctuation',
#  ']=/Punctuation',
#  '?/Punctuation에/Josa',
#  '만으로/Josa',
#  '^^;/Punctuation',
#  '는/Josa)/Punctuation',
#  ",/Punctuation'/Punctuation",
#  ">'/Punctuation>/Punctuation",
#  '여/Josa하고/Josa',
#  '#./Punctuation',
#  "',/Punctuation에서/Josa",
#  '인/Josa)/Punctuation',
#  '!!!",/Punctuation',
#  '만/Josa',
#  ",'/Punctuation",
#  '했지만/Josa으로는/Josa',
#  '?/Punctuation>/Punctuation',
#  '까지라도/Josa',
#  '=/Punctuation',
#  '으로부터의/Josa에/Josa',
#  '까지는/Josa라는/Josa',
#  '.?/Punctuation',
#  '은/Josa이고/Josa',
#  './/Punctuation)/Punctuation',
#  '지/Josa',
#  '.##/Punctuation',
#  '?:/Punctuation',
#  '("/Punctuation',
#  ':(/Punctuation',
#  '!!]/Punctuation',
#  '..."/Punctuation',
#  '!"]/Punctuation',
#  '으로부터는/Josa',
#  '으로/Josa마다/Josa',
#  '했기에/Josa',
#  "'(/Punctuation도/Josa",
#  ',?/Punctuation',
#  '로군요/Josa',
#  '조차가/Josa',
#  ".'/Punctuation",
#  '으로부터의/Josa>/Punctuation',
#  ',/Punctuation이지만/Josa',
#  '까지/Josa에/Josa',
#  '][/Punctuation)/Punctuation',
#  '보다야/Josa',
#  '""\'/Punctuation</Punctuation',
#  '로는/Josa인데/Josa',
#  ')-"(/Punctuation',
#  '난/Josa에서/Josa',
#  '..-/Punctuation',
#  '밖에도/Josa',
#  "'[</Punctuation</Punctuation",
#  '와는/Josa',
#  '치고/Josa',
#  '로고/Josa',
#  '?."/Punctuation',
#  '을/Josa에/Josa',
#  '~.""/Punctuation',
#  '여/Josa을/Josa',
#  '.)][/Punctuation',
#  '!!/Punctuation',
#  ',</Punctuation',
#  '.-</Punctuation',
#  '.\'"/Punctuation',
#  '>>,/Punctuation',
#  "',/Punctuation>/Punctuation",
#  '-/Punctuation',
#  '으로/Josa에서/Josa',
#  ')[</Punctuation)/Punctuation',
#  '만에/Josa',
#  '까진/Josa',
#  ')-/Punctuation',
#  '!)/Punctuation',
#  "'-'/Punctuation",
#  '만큼/Josa을/Josa',
#  '으로만/Josa',
#  '인즉/Josa',
#  '나/Josa)/Punctuation',
#  '으로부터/Josa을/Josa',
#  '*****)/Punctuation',
#  "%)','/Punctuation",
#  ".]'/Punctuation",
#  '으로선/Josa)/Punctuation',
#  '.-----/Punctuation',
#  ")'[</Punctuation",
#  "')/Punctuation)/Punctuation",
#  "만이/Josa'/Punctuation",
#  '니까/Josa)/Punctuation',
#  '.{/Punctuation',
#  '\'."/Punctuation에/Josa',
#  "')'/Punctuation",
#  '.).]/Punctuation',
#  '하고는/Josa',
#  '엔/Josa~/Punctuation',
#  '만이/Josa라도/Josa',
#  '.),/Punctuation',
#  '======/Punctuation',
#  '"...?"/Punctuation',
#  '난/Josa에/Josa',
#  "'('/Punctuation",
#  '!"(/Punctuation',
#  '한/Josa</Punctuation',
#  '에게/Josa',
#  '나/Josa에/Josa',
#  '></Punctuation',
#  "'.-/Punctuation",
#  "~'/Punctuation>/Punctuation",
#  '도/Josa에/Josa',
#  '는/Josa마다/Josa',
#  '(/Punctuation</Punctuation',
#  '한/Josa까지로/Josa',
#  '%/Punctuation',
#  ']*/Punctuation',
#  '?/Punctuation]/Punctuation',
#  ')/(/Punctuation',
#  '같인/Josa',
#  '에서나마/Josa',
#  '%(-/Punctuation',
#  "+',/Punctuation",
#  "'#(/Punctuation",
#  '은커녕/Josa',
#  '(...)"/Punctuation',
#  '~~~/Punctuation',
#  '(,)/Punctuation',
#  ')"]/Punctuation에/Josa',
#  '으로선/Josa로/Josa',
#  '만큼/Josa',
#  '까지로/Josa',
#  '"-"/Punctuation',
#  '밖에/Josa</Punctuation',
#  '에서부터/Josa',
#  '----------------------------------------------------------------------------------------------------------------------------------------------------/Punctuation에/Josa',
#  '),/Punctuation</Punctuation',
#  '든/Josa',
#  '*(/Punctuation',
#  '...""/Punctuation',
#  '+/Punctuation>/Punctuation',
#  '했지만/Josa=</Punctuation',
#  '\'."-/Punctuation',
#  '에선/Josa</Punctuation',
#  ',/Punctuation>]/Punctuation',
#  '.[</Punctuation',
#  '::/Punctuation',
#  '은/Josa로/Josa',
#  '%%/Punctuation',
#  '와만/Josa',
#  '~/Punctuation',
#  '니/Josa',
#  "?'/Punctuation에/Josa",
#  '(="/Punctuation',
#  '와도/Josa',
#  '??/Punctuation',
#  "')/Punctuation",
#  '만으로도/Josa와는/Josa',
#  '....../Punctuation',
#  '......"</Punctuation</Punctuation',
#  '밖에는/Josa',
#  '.@@@/Punctuation',
#  '?)][/Punctuation',
#  '이니까/Josa',
#  '!"\'/Punctuation',
#  ')]"(/Punctuation',
#  ')./Punctuation',
#  '했지만/Josa</Punctuation',
#  '인지/Josa',
#  ',/Punctuation을/Josa',
#  '만으론/Josa',
#  '?"(/Punctuation',
#  '.+++/Punctuation',
#  '********)"/Punctuation',
#  '.]++[/Punctuation',
#  '......"/Punctuation',
#  '으로든지/Josa',
#  '~"/Punctuation',
#  "(?)'/Punctuation",
#  "'.[/Punctuation",
#  '>:/Punctuation',
#  '](/Punctuation',
#  '_/Punctuation',
#  ')<<</Punctuation',
#  "?)'/Punctuation",
#  "')/Punctuation</Punctuation",
#  ',/Punctuation>/Punctuation',
#  '했지만/Josa하고/Josa',
#  '(,/Punctuation',
#  '엔/Josa이고/Josa',
#  ')]/Punctuation',
#  '!-/Punctuation',
#  '((/Punctuation',
#  ',/Punctuation만에/Josa',
#  '에요/Josa에/Josa',
#  '보다/Josa!"/Punctuation',
#  '마따나/Josa',
#  ")...'/Punctuation",
#  '~""/Punctuation에/Josa',
#  ']/Punctuation',
#  '도/Josa</Punctuation',
#  '와/Josa',
#  '만의/Josa',
#  '같이/Josa</Punctuation',
#  '라고까지/Josa에/Josa',
#  '(?)//Punctuation',
#  '\'."/Punctuation>/Punctuation',
#  '로운/Josa인데/Josa',
#  '은/Josa에서/Josa',
#  '****)/Punctuation',
#  '%)"/Punctuation에/Josa',
#  '\'"/Punctuation',
#  '대로가/Josa',
#  '에서까지/Josa</Punctuation',
#  '에게까지/Josa',
#  '만으로는/Josa)/Punctuation',
#  '께서/Josa>/Punctuation',
#  '께선/Josa',
#  '만으로는/Josa</Punctuation',
#  ',/Punctuation하고/Josa',
#  "%.'/Punctuation",
#  "?',/Punctuation>/Punctuation",
#  '?]/Punctuation</Punctuation',
#  '.)-/Punctuation',
#  '>=/Punctuation',
#  '대로의/Josa>/Punctuation',
#  '으로선/Josa에/Josa',
#  "''(/Punctuation",
#  ')."</Punctuation',
#  "는/Josa'/Punctuation",
#  '보다/Josa>]/Punctuation',
#  '>.../Punctuation',
#  '>)-/Punctuation에/Josa',
#  '하오/Josa',
#  '이라기/Josa',
#  '.")"/Punctuation',
#  ")'/Punctuation]/Punctuation",
#  '{/Punctuation',
#  '-(/Punctuation에/Josa',
#  '?/Punctuation이고/Josa',
#  "'/Punctuation",
#  '*/Punctuation',
#  '보다/Josa을/Josa',
#  '...",/Punctuation',
#  '같이/Josa)/Punctuation',
#  '부터도/Josa',
#  '이라니/Josa',
#  '?+++/Punctuation',
#  '!"./Punctuation',
#  '같이/Josa하고/Josa',
#  '만으로도/Josa에서/Josa',
#  ')%(/Punctuation',
#  ']((/Punctuation에/Josa',
#  '>]--/Punctuation',
#  '...")./Punctuation',
#  ':"/Punctuation',
#  '?_/Punctuation',
#  '인게/Josa에/Josa',
#  '"<\'/Punctuation',
#  '>](/Punctuation',
#  '^/Punctuation',
#  '까지가/Josa',
#  '니까/Josa에서부터/Josa',
#  "***'/Punctuation",
#  '만을/Josa',
#  "',/Punctuation로/Josa",
#  '..."-/Punctuation',
#  '?!,/Punctuation',
#  '.]/Punctuation에/Josa',
#  '을/Josa',
#  '마다의/Josa',
#  "'...'/Punctuation",
#  '대로가/Josa에/Josa',
#  ')/</Punctuation',
#  '~!/Punctuation',
#  '에게서/Josa</Punctuation',
#  '라든지/Josa',
#  '으로써/Josa에/Josa',
#  ">'/Punctuation에/Josa",
#  '에서만/Josa에/Josa',
#  '까지라도/Josa에/Josa',
#  '."<\'/Punctuation',
#  '!>/Punctuation',
#  '같이/Josa=/Punctuation',
#  ')[</Punctuation>/Punctuation',
#  '!,/Punctuation',
#  "'~/Punctuation",
#  '엔/Josa이라고는/Josa',
#  '요/Josa',
#  '까지나/Josa',
#  '은/Josa죠/Josa',
#  '에게선/Josa',
#  '와도/Josa</Punctuation',
#  '라고까지/Josa',
#  '에로/Josa',
#  '조차/Josa>/Punctuation',
#  '?/Punctuation으로부터도/Josa',
#  ')./Punctuation>/Punctuation',
#  ',/Punctuation?)[/Punctuation',
#  '에서라도/Josa',
#  '....."/Punctuation',
#  '에서만큼은/Josa',
#  '\\/Punctuation',
#  '난/Josa을/Josa',
#  ',/Punctuation%./Punctuation',
#  '+++[/Punctuation',
#  '여서/Josa에/Josa',
#  '으로부터/Josa인데/Josa',
#  '까지는/Josa하고/Josa',
#  '만으로도/Josa을/Josa',
#  '한/Josa',
#  '.]+++/Punctuation',
#  '에다가는/Josa',
#  '까지로만/Josa',
#  ".',/Punctuation",
#  '%[/Punctuation',
#  '에서와의/Josa에/Josa',
#  "!'/Punctuation",
#  '..."</Punctuation',
#  '으로부터/Josa라도/Josa',
#  '~~"/Punctuation',
#  '만으로도/Josa로/Josa',
#  '.#/Punctuation</Punctuation',
#  '?\'."/Punctuation',
#  '"~/Punctuation',
#  '")."/Punctuation',
#  "!'./Punctuation",
#  '"[/Punctuation',
#  ')<"/Punctuation',
#  '만/Josa에서/Josa',
#  '과/Josa',
#  '말고도/Josa',
#  "****'/Punctuation",
#  './/Punctuation에/Josa',
#  "'.][/Punctuation",
#  '이고/Josa',
#  '만으로도/Josa에/Josa',
#  '만으로는/Josa에/Josa',
#  '에서는/Josa에/Josa',
#  ',./Punctuation',
#  '?.../Punctuation',
#  '고/Josa</Punctuation',
#  '만큼이라도/Josa',
#  '만/Josa에/Josa',
#  '대로/Josa)/Punctuation',
#  '-----------------------/Punctuation',
#  '>,/Punctuation',
#  "'!/Punctuation",
#  '같이/Josa을/Josa',
#  '!?./Punctuation',
#  '을/Josa>/Punctuation',
#  '@@@@/Punctuation',
#  '>./Punctuation',
#  '은/Josa]/Punctuation',
#  '...)"/Punctuation',
#  '으로까지/Josa',
#  '인/Josa',
#  "'(/Punctuation'/Punctuation",
#  '......./Punctuation',
#  '밖에/Josa)/Punctuation',
#  ',"-/Punctuation',
#  '..)"/Punctuation',
#  '은/Josa인데/Josa',
#  '?"[</Punctuation',
#  '하고만/Josa',
#  '?)//Punctuation',
#  ',/Punctuation인데/Josa',
#  '%#/Punctuation',
#  '네/Josa',
#  "<'/Punctuation",
#  '!"[/Punctuation',
#  '로는/Josa>/Punctuation',
#  '께서/Josa든/Josa',
#  ")'/Punctuation>/Punctuation",
#  "'(/Punctuation",
#  "'</Punctuation",
#  '".../Punctuation',
#  '으로써/Josa인데/Josa',
#  '".../Punctuation에서/Josa',
#  '엔/Josa인데/Josa',
#  '\'")/Punctuation',
#  ')"-/Punctuation',
#  ')):/Punctuation에/Josa',
#  '에게다/Josa',
#  '이던/Josa',
#  ';)/Punctuation',
#  '\')]"/Punctuation',
#  '보다/Josa=/Punctuation',
#  '으로써/Josa마다/Josa',
#  '만치/Josa에/Josa',
#  '같이/Josa인데/Josa',
#  '이오니/Josa',
#  '이야말로/Josa',
#  "')./Punctuation",
#  '>=/Punctuation에/Josa',
#  './</Punctuation',
#  '.<<</Punctuation',
#  '만이/Josa</Punctuation',
#  '까지는/Josa이고/Josa',
#  '라고/Josa',
#  '->/Punctuation',
#  '\'""/Punctuation',
#  '지/Josa</Punctuation',
#  '대로/Josa>/Punctuation',
#  '지/Josa에/Josa',
#  '한/Josa=</Punctuation',
#  ',/Punctuation에서부터/Josa',
#  '에다가/Josa',
#  ',/Punctuation해서/Josa',
#  '께서/Josa에/Josa',
#  '!!!/Punctuation',
#  './/Punctuation>/Punctuation',
#  '난/Josa이어서/Josa',
#  '(+/Punctuation',
#  '일텐데/Josa</Punctuation',
#  '.(/Punctuation에/Josa',
#  '*********)/Punctuation',
#  '!!"</Punctuation',
#  ">'/Punctuation에서/Josa",
#  "']/Punctuation%/Punctuation",
#  ']"/Punctuation에서/Josa',
#  '만이/Josa=</Punctuation',
#  '엔/Josa든/Josa',
#  '][/Punctuation>/Punctuation',
#  '만으로도/Josa)/Punctuation',
#  '>[/Punctuation',
#  '%%,/Punctuation',
#  '~"-/Punctuation',
#  '일텐데/Josa)/Punctuation',
#  ')/Punctuation',
#  '으로야/Josa',
#  '"/Punctuation',
#  '>-/Punctuation',
#  '으로/Josa',
#  '에게서도/Josa',
#  '%+/Punctuation',
#  '."]/Punctuation에/Josa',
#  '대로는/Josa',
#  '~~~]/Punctuation',
#  '">/Punctuation>/Punctuation',
#  ',(/Punctuation',
#  '~~~~~~/Punctuation',
#  '(+)./Punctuation',
#  '이야/Josa',
#  '부터만/Josa',
#  '에까지/Josa',
#  '>)/Punctuation',
#  '."..."-/Punctuation',
#  '?#/Punctuation',
#  ')~/Punctuation',
#  '**),/Punctuation',
#  '부터의/Josa',
#  '**)/Punctuation에/Josa',
#  '...?)/Punctuation',
#  ',,/Punctuation</Punctuation',
#  '가/Josa에/Josa',
#  '께서/Josa서/Josa',
#  '!!!!!"/Punctuation',
#  '니까/Josa에/Josa',
#  "****')/Punctuation",
#  '으로/Josa에/Josa',
#  '에서와/Josa',
#  '대로가/Josa</Punctuation',
#  ".'-/Punctuation",
#  '(***)/Punctuation',
#  '*****)"/Punctuation',
#  ')..."/Punctuation',
#  '?][/Punctuation',
#  ')]-/Punctuation',
#  '만이/Josa로/Josa',
#  '이며/Josa',
#  "%'/Punctuation",
#  '\'""(/Punctuation',
#  '/(/Punctuation',
#  '조차를/Josa',
#  '===================================================================================/Punctuation',
#  '?~/Punctuation',
#  '!)][/Punctuation',
#  '으론/Josa',
#  '%,/Punctuation에/Josa',
#  '[/Punctuation',
#  '."-\'/Punctuation',
#  '[[/Punctuation',
#  '이니/Josa에/Josa',
#  '서/Josa',
#  ']</Punctuation',
#  "',/Punctuation에/Josa",
#  ').../Punctuation',
#  '에든/Josa',
#  "한/Josa'/Punctuation",
#  '에서는/Josa',
#  ',/Punctuation이고/Josa',
#  ')=</Punctuation',
#  '~</Punctuation',
#  '한/Josa인데/Josa',
#  '도/Josa',
#  "',/Punctuation이고/Josa",
#  '하고도/Josa에/Josa',
#  ";'/Punctuation",
#  '.....]/Punctuation',
#  '로운/Josa',
#  '으로부터도/Josa',
#  '엔/Josa%/Punctuation',
#  '스럽지/Josa',
#  '했지만/Josa라도/Josa',
#  '대로/Josa에/Josa',
#  "('</Punctuation",
#  '?/Punctuation서/Josa',
#  "%'(/Punctuation",
#  '부터/Josa',
#  '?/Punctuation하고/Josa',
#  '>/Punctuation</Punctuation',
#  '.#./Punctuation',
#  '이다/Josa)/Punctuation',
#  '라는/Josa',
#  ')."(/Punctuation',
#  '!""/Punctuation',
#  '"[</Punctuation',
#  '했지만/Josa지는/Josa',
#  '.<</Punctuation에/Josa',
#  '까지/Josa</Punctuation',
#  '이라든지/Josa에/Josa',
#  '인거/Josa',
#  '.["/Punctuation',
#  '와도/Josa에/Josa',
#  '에게서/Josa)/Punctuation',
#  '엔/Josa하고/Josa',
#  ">-'/Punctuation",
#  ':/Punctuation',
#  '니깐/Josa',
#  ',/Punctuation밖에도/Josa',
#  ')%/Punctuation',
#  "'/>/Punctuation",
#  '?/Punctuation처럼/Josa',
#  '...)/Punctuation',
#  '와도/Josa>/Punctuation',
#  '//Punctuation',
#  '으로선/Josa>/Punctuation',
#  "?'-/Punctuation",
#  '보다/Josa./Punctuation',
#  '했기에/Josa에/Josa',
#  '),)/Punctuation',
#  '에선/Josa',
#  '<"/Punctuation',
#  ',/Punctuation든/Josa',
#  '하고는/Josa>/Punctuation',
#  ".',/Punctuation에/Josa",
#  ",''/Punctuation",
#  ')//Punctuation',
#  '에서만/Josa)/Punctuation',
#  '********/Punctuation',
#  "까지는/Josa'/Punctuation",
#  '%,/Punctuation>/Punctuation',
#  '."-/Punctuation에/Josa',
#  '>(</Punctuation',
#  '%.../Punctuation',
#  "%)'/Punctuation",
#  '으로/Josa%),/Punctuation',
#  '%->/Punctuation',
#  '.>-/Punctuation에/Josa',
#  '고/Josa)/Punctuation',
#  "')/Punctuation>/Punctuation",
#  '밖에/Josa에서/Josa',
#  '이/Josa로/Josa',
#  '보다/Josa마다/Josa',
#  '인/Josa에/Josa',
#  '야/Josa',
#  '?>[/Punctuation',
#  '()/Punctuation',
#  '이를/Josa',
#  ">]'/Punctuation",
#  '**/Punctuation',
#  '(?!)/Punctuation',
#  '고/Josa인데/Josa',
#  '여서/Josa에서/Josa',
#  '에요/Josa>/Punctuation',
#  '.+++[/Punctuation',
#  '[/Punctuation에/Josa',
#  '만큼/Josa]/Punctuation',
#  '에다/Josa',
#  '.)/Punctuation',
#  '만으로는/Josa>/Punctuation',
#  "')-/Punctuation>/Punctuation",
#  '.(?)/Punctuation',
#  '?"[/Punctuation',
#  ",/Punctuation'..'/Punctuation",
#  '?{/Punctuation',
#  '보다/Josa까지로/Josa',
#  '">/Punctuation에/Josa',
#  ',/Punctuation서/Josa',
#  "!',/Punctuation",
#  '으로는/Josa',
#  '며/Josa',
#  '"`/Punctuation에/Josa',
#  "_****'/Punctuation",
#  '여/Josa에서/Josa',
#  '>.-/Punctuation',
#  '***)/Punctuation',
#  '까지를/Josa',
#  "','/Punctuation",
#  '에서의/Josa',
#  '.---------------------/Punctuation',
#  '조차도/Josa',
#  '******/Punctuation',
#  '까지는/Josa에/Josa',
#  '에게서/Josa',
#  '.""\'/Punctuation',
#  '에/Josa',
#  '보다/Josa하고/Josa',
#  "]'/Punctuation",
#  '%)(-/Punctuation',
#  "~',/Punctuation",
#  '인/Josa>/Punctuation',
#  '---/Punctuation',
#  "+'/Punctuation",
#  '?/Punctuation으로는/Josa',
#  '까지는/Josa이지만/Josa',
#  '\'..."/Punctuation',
#  "['/Punctuation",
#  ')"/Punctuation',
#  '라든가/Josa',
#  '은/Josa)/Punctuation',
#  '....[/Punctuation',
#  ')-"/Punctuation',
#  '(*/Punctuation',
#  '%../Punctuation',
#  '~?-/Punctuation',
#  '!\'"/Punctuation',
#  '커녕/Josa',
#  '에서와는/Josa',
#  '라고는/Josa',
#  '으로/Josa</Punctuation',
#  '은/Josa라도/Josa',
#  '~^^"/Punctuation',
#  '----------------------------------------------------/Punctuation',
#  '했지만/Josa난/Josa',
#  '같이/Josa라도/Josa',
#  '니까/Josa>/Punctuation',
#  '지/Josa>/Punctuation',
#  '이야/Josa>/Punctuation',
#  '으로/Josa이고/Josa',
#  './/Punctuation',
#  ')?"-/Punctuation',
#  '.\'"-/Punctuation',
#  '?/Punctuation~/Punctuation',
#  '%),/Punctuation',
#  '와도/Josa에서/Josa',
#  '한테/Josa에서/Josa',
#  '"?/Punctuation',
#  '"*</Punctuation',
#  "'?',/Punctuation",
#  '?)"/Punctuation',
#  ').,/Punctuation',
#  '와를/Josa',
#  '했지만/Josa>/Punctuation',
#  '에부터/Josa',
#  '이구나/Josa',
#  '로되/Josa',
#  '>_/Punctuation에/Josa',
#  ".--'/Punctuation",
#  '?//Punctuation',
#  '같이/Josa마다/Josa',
#  '.""/Punctuation',
#  '<<</Punctuation',
#  '라던가/Josa',
#  '~?)/Punctuation',
#  ',/Punctuation에는/Josa',
#  "',/Punctuation./Punctuation",
#  "='/Punctuation",
#  '."</Punctuation',
#  '"-/Punctuation',
#  '에로의/Josa',
#  '(),/Punctuation',
#  ')+/Punctuation',
#  "'-/Punctuation",
#  '.]@@@/Punctuation',
#  '~!+++/Punctuation',
#  ")'/Punctuation에서/Josa",
#  '</Punctuation',
#  '이/Josa)/Punctuation',
#  '만큼/Josa에서/Josa',
#  '는/Josa에/Josa',
#  ')(/Punctuation',
#  '하고는/Josa)/Punctuation',
#  '.|/Punctuation',
#  '을/Josa</Punctuation',
#  '.-./Punctuation',
#  '..."-(/Punctuation',
#  '.<</Punctuation>/Punctuation',
#  '엔/Josa에/Josa',
#  '.%/Punctuation',
#  '과/Josa</Punctuation',
#  '>(/Punctuation',
#  '.)]/Punctuation',
#  '이라/Josa)/Punctuation',
#  '으로도/Josa',
#  '은/Josa)"-/Punctuation',
#  '으로/Josa)/Punctuation',
#  '한/Josa하고/Josa',
#  '은/Josa하고/Josa',
#  '**)/Punctuation',
#  '만큼/Josa</Punctuation',
#  '>),/Punctuation',
#  ',,,/Punctuation',
#  '...?.../Punctuation',
#  '이기도/Josa',
#  './Punctuation에/Josa',
#  '께서/Josa이지만/Josa',
#  ';,/Punctuation',
#  "으로/Josa'/Punctuation",
#  '?/Punctuation인지/Josa',
#  '만도/Josa',
#  '으로부터/Josa이고/Josa',
#  '?)./Punctuation',
#  '`/Punctuation',
#  '과만/Josa',
#  ')[/Punctuation',
#  "'(/Punctuation=</Punctuation",
#  '까지/Josa에서/Josa',
#  '에서야/Josa',
#  "*********)'/Punctuation",
#  '엔/Josa>/Punctuation',
#  '가/Josa',
#  '"(?)/Punctuation',
#  '()//Punctuation',
#  '>[</Punctuation',
#  '난/Josa마다/Josa',
#  '만으로도/Josa>/Punctuation',
#  '\'"\'/Punctuation',
#  ']?/Punctuation',
#  '>)./Punctuation',
#  '엔/Josa)/Punctuation',
#  '인즉슨/Josa',
#  '![/Punctuation',
#  '!)"/Punctuation',
#  '에서도/Josa',
#  '...</Punctuation',
#  ',/Punctuation으로부터도/Josa',
#  '?</Punctuation',
#  '만큼이나/Josa',
#  '에서의/Josa에/Josa',
#  '엔/Josa까지로/Josa',
#  '로운/Josa>/Punctuation',
#  '으로써/Josa)/Punctuation',
#  '%)%/Punctuation',
#  '께서/Josa도/Josa',
#  '(=/Punctuation',
#  ',/Punctuation라도/Josa',
#  '.",/Punctuation',
#  '롭고/Josa',
#  '나/Josa>/Punctuation',
#  '".../Punctuation)/Punctuation',
#  '에서까지/Josa>/Punctuation',
#  '.#/Punctuation에/Josa',
#  '%:/Punctuation',
#  ',/Punctuation</Punctuation',
#  ')"(/Punctuation',
#  '처럼도/Josa',
#  '?+++</Punctuation',
#  '한/Josa)/Punctuation',
#  ...]

# %%
#stopwords 저장
import pickle

lst = stopwords
with open('stopwords.txt', 'wb') as f:
    pickle.dump(lst, f)
    
# with open('stopwords.txt', 'rb') as f:
#     p_X = pickle.load(f)

# %%
stw = list(stopwords)

# %%
train_df.text[:2]
# Out:
# 0    [앵커]청와대 민정수석을 지냈던 우병우씨의 소재를 놓고 설왕설래가 한창입니다. 지난...
# 1    [<언론사명>]새누리당 원내대표 경선을 하루 앞둔 2일 청와대는 사실상 ‘불개입’ ...
# Name: text, dtype: object

# %%
# vectorize train using Tfid(bag of words)

twitter = Twitter()

def tokenize_pos(doc):
    return ['/'.join(t) for t in twitter.pos(doc, norm=True, stem=True)]

vectorizer =  TfidfVectorizer(tokenizer=tokenize_pos, ngram_range=(1,2),
                              use_idf=False, smooth_idf=False, stop_words=stw
                              )
#X = vectorizer.fit_transform(X)
X = vectorizer.fit_transform(train_df.text)

# %%
X.shape
# Out:
# (76500, 3558727)

# %%
# # sparse matrix test
# import random
# import scipy.sparse as sparse
# import scipy.io
# import numpy as np

# def save_sparse_matrix(filename, x):
#     x_coo = x.tocoo()
#     row = x_coo.row
#     col = x_coo.col
#     data = x_coo.data
#     shape = x_coo.shape
#     np.savez(filename, row=row, col=col, data=data, shape=shape)

# def load_sparse_matrix(filename):
#     y = np.load(filename)
#     z = sparse.coo_matrix((y['data'], (y['row'], y['col'])), shape=y['shape'])
#     return z

# N=20000
# x = sparse.lil_matrix( (N,N) )
# for i in xrange(N):
#     x[random.randint(0,N-1),random.randint(0,N-1)]=random.randint(1,100)

# save_sparse_matrix('/tmp/my_array',x)
# load_sparse_matrix('/tmp/my_array.npz').tolil()

# %% [markdown]
# ### Fitting train data

# %%
import xgboost
# Out:
# /Users/yoo/anaconda/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
# fitting train data with classifier

#model = SGDClassifier(alpha=1.9e-6, n_iter=19).fit(X, y)
#model = LogisticRegression(C=10).fit(X,y)
#model = xgboost.XGBClassifier().fit(X,y)
#model = MultinomialNB(alpha=0.01).fit(X,y)
model = ExtraTreesClassifier(n_estimators=100).fit(X,y)

# %%
# Out:
# <1x1 sparse matrix of type '<class 'numpy.float64'>'
# 	with 0 stored elements in Compressed Sparse Row format>

# %%
feature_list = vectorizer.get_feature_names()
pos_list = pd.DataFrame(feature_list,columns=['pos'])
reduced_feature_list = pos_list[pos_list.pos.str.contains('Josa')==False]

reduced_feature_list.shape
# Out:
# (1941228, 1)

# %%
# # predict test data

# def testX_to_vec(X):
#     feature_list = vectorizer.get_feature_names()

#     test_vectorizer =  TfidfVectorizer(tokenizer=tokenize_pos, ngram_range=(1,2), vocabulary = feature_list)
#     X_test = test_vectorizer.fit_transform(X)
    
#     return X_test

# %%
# reduced feature) predict test data

def testX_to_vec(X):
    feature_list = vectorizer.get_feature_names()

    test_vectorizer =  TfidfVectorizer(tokenizer=tokenize_pos, ngram_range=(1,2), vocabulary = feature_list)
    X_test = test_vectorizer.fit_transform(X)
    
    return X_test

# %%
test_X[0]
# Out:
# <1x3558727 sparse matrix of type '<class 'numpy.float64'>'
# 	with 197 stored elements in Compressed Sparse Row format>

# %%
#test to vec
test_X = testX_to_vec(test_df.text)

# %%
#test to vec
test_rank = predict_rank(test_X)

# %%
mrr(test_rank,test_df.writing) # forest est 100
# Out:
# 0.67307752117450259

# %%
# Logistic C=10
test_pred = model.predict(test_X)

# accuracy
print(accuracy_score(test_df.writing, test_pred))


print(classification_report(test_df.writing, test_pred))
# Out:
# 0.663777777778
#              precision    recall  f1-score   support
#
#        JTBC       0.90      0.62      0.73       139
#      KBS 뉴스       0.75      0.81      0.78       372
#         MBN       0.93      0.71      0.81       437
#        TV조선       0.94      0.56      0.70        90
#         YTN       0.74      0.78      0.76       232
#        경향신문       0.67      0.40      0.50       100
#        국민일보       0.47      0.69      0.56       336
#        노컷뉴스       0.92      0.69      0.79        35
#         뉴시스       0.71      0.84      0.77       661
#        동아일보       0.81      0.65      0.72       290
#        매일경제       0.56      0.50      0.53       186
#        서울신문       0.82      0.37      0.51       253
#       아시아경제       0.86      0.12      0.22        48
#        연합뉴스       0.98      0.27      0.42       487
#      연합뉴스TV       0.55      0.88      0.68       191
#       오마이뉴스       1.00      0.74      0.85       121
#         채널A       0.67      0.97      0.79       122
#      파이낸셜뉴스       0.40      0.86      0.55       243
#       헤럴드경제       0.43      0.71      0.53       157
#
# avg / total       0.74      0.66      0.66      4500

# %%
# NB
test_pred = model.predict(X_test)

# accuracy
print(accuracy_score(test_df.writing, test_pred))
# 0.8111

print(classification_report(test_df.writing, test_pred))
# Out:
# 0.600222222222
#              precision    recall  f1-score   support
#
#        JTBC       0.88      0.58      0.70       139
#      KBS 뉴스       0.66      0.59      0.62       372
#         MBN       0.69      0.73      0.71       437
#        TV조선       1.00      0.14      0.25        90
#         YTN       0.70      0.79      0.74       232
#        경향신문       0.75      0.03      0.06       100
#        국민일보       0.41      0.46      0.43       336
#        노컷뉴스       1.00      0.17      0.29        35
#         뉴시스       0.62      0.81      0.70       661
#        동아일보       0.50      0.76      0.61       290
#        매일경제       0.45      0.27      0.34       186
#        서울신문       0.51      0.38      0.44       253
#       아시아경제       0.00      0.00      0.00        48
#        연합뉴스       0.51      0.82      0.62       487
#      연합뉴스TV       0.75      0.70      0.72       191
#       오마이뉴스       0.86      0.66      0.75       121
#         채널A       0.92      0.54      0.68       122
#      파이낸셜뉴스       0.59      0.41      0.48       243
#       헤럴드경제       0.84      0.29      0.43       157
#
# avg / total       0.63      0.60      0.58      4500
# /Users/yoo/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
# forest
test_pred = model.predict(X_test)

# accuracy
print(accuracy_score(test_df.writing, test_pred))
# 0.8111

print(classification_report(test_df.writing, test_pred))
# Out:
# 0.582888888889
#              precision    recall  f1-score   support
#
#        JTBC       0.64      0.55      0.59       139
#      KBS 뉴스       0.65      0.84      0.73       372
#         MBN       0.67      0.73      0.70       437
#        TV조선       0.71      0.49      0.58        90
#         YTN       0.72      0.67      0.69       232
#        경향신문       0.21      0.08      0.12       100
#        국민일보       0.33      0.36      0.34       336
#        노컷뉴스       1.00      0.63      0.77        35
#         뉴시스       0.45      0.88      0.60       661
#        동아일보       0.50      0.56      0.53       290
#        매일경제       0.38      0.06      0.10       186
#        서울신문       0.49      0.36      0.41       253
#       아시아경제       0.89      0.17      0.28        48
#        연합뉴스       0.79      0.68      0.73       487
#      연합뉴스TV       0.84      0.65      0.74       191
#       오마이뉴스       1.00      0.64      0.78       121
#         채널A       0.84      0.70      0.76       122
#      파이낸셜뉴스       0.74      0.26      0.38       243
#       헤럴드경제       0.68      0.20      0.31       157
#
# avg / total       0.61      0.58      0.56      4500

# %%
#logistic
test_pred = model.predict(X_test)

# accuracy
print(accuracy_score(test_df.writing, test_pred))
# 0.8111

print(classification_report(test_df.writing, test_pred))
# Out:
# 0.811111111111
#              precision    recall  f1-score   support
#
#        JTBC       1.00      0.71      0.83       139
#      KBS 뉴스       0.92      0.90      0.91       372
#         MBN       0.95      0.93      0.94       437
#        TV조선       1.00      0.86      0.92        90
#         YTN       0.76      0.94      0.84       232
#        경향신문       0.66      0.60      0.63       100
#        국민일보       0.54      0.85      0.66       336
#        노컷뉴스       1.00      0.74      0.85        35
#         뉴시스       0.88      0.95      0.92       661
#        동아일보       0.92      0.72      0.81       290
#        매일경제       0.71      0.55      0.62       186
#        서울신문       0.95      0.38      0.54       253
#       아시아경제       1.00      0.35      0.52        48
#        연합뉴스       1.00      0.75      0.86       487
#      연합뉴스TV       0.93      0.94      0.93       191
#       오마이뉴스       1.00      0.64      0.78       121
#         채널A       0.95      0.99      0.97       122
#      파이낸셜뉴스       0.55      0.92      0.68       243
#       헤럴드경제       0.56      0.78      0.65       157
#
# avg / total       0.85      0.81      0.81      4500

# %%
#xgboost
test_pred = model.predict(X_test)

# accuracy
print(accuracy_score(test_df.writing, test_pred))
# 0.8111

print(classification_report(test_df.writing, test_pred))
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
def predict_rank(X_test):
    
    test_prob = model.predict_proba(X_test)

    test_class = pd.DataFrame((-test_prob).argsort())
    
    class_df = pd.DataFrame(model.classes_).reset_index()
    
    # data frame 생성
    for i in range(len(model.classes_)):
        class_df.columns = [i, 'rank_'+str(i)]
        test_class = pd.merge(test_class, class_df, on=i, how='left')

    # rank columns    
    rank_columns = ['rank_0',  'rank_1',  'rank_2',  'rank_3',  'rank_4',
                    'rank_5',  'rank_6',  'rank_7',  'rank_8',  'rank_9', 
                    'rank_10', 'rank_11', 'rank_12', 'rank_13', 'rank_14', 
                    'rank_15', 'rank_16', 'rank_17', 'rank_18']

    #dataframe to csv
    test_class_csv = test_class[rank_columns].to_csv(header=False, index=False)
    test_class_csv = test_class_csv.splitlines()
    
    return test_class_csv#test_class_csv[0], '...\n \n ', test_class_csv[-1]

# %%
# predict rank
rank_class = predict_rank(test_X) # test score 0.87846

# %%
# predict 결과 확인
rank_class[:2]
# Out:
# ['연합뉴스,아시아경제,뉴시스,파이낸셜뉴스,JTBC,채널A,오마이뉴스,연합뉴스TV,서울신문,매일경제,동아일보,국민일보,경향신문,YTN,TV조선,MBN,KBS 뉴스,노컷뉴스,헤럴드경제',
#  '뉴시스,연합뉴스,MBN,JTBC,채널A,오마이뉴스,연합뉴스TV,아시아경제,서울신문,매일경제,동아일보,노컷뉴스,국민일보,경향신문,YTN,TV조선,KBS 뉴스,파이낸셜뉴스,헤럴드경제']

# %%
# write csv
output_file = 'submission.txt'
with open(output_file, 'w') as fp:
    for row in rank_class:
        fp.write(row)
        fp.write('\n')

# %% [markdown]
# #### MRR

# %%
def mrr(rank_class, test_out_data):

    pred = []
    for i in range(len(rank_class)):
        pred.append(rank_class[i].split(','))
    
    position = np.zeros([len(rank_class),1])
    pred = np.array(pred)
    test_true = np.array(test_out_data)
    
    for i in range(len(rank_class)):
        position[i] = np.where(pred[i]==test_true[i])[0]+1
    
    return ((1/position).sum())/len(rank_class)

# %%
mrr(rank_class, test_out_data)
# Out:
# 0.77340329438172573

# %% [markdown]
# #### Predict grading_data

# %%
grading_df['text'][20:30]
# Out:
# 20    취재진 질문에 답하는 조인근 전 비서관\n    (서울=<언론사명>)  = 조인근 ...
# 21    [<언론사명>]사진=<언론사명> 캡처 ‘최순실 게이트’의 핵심 증거 중 하나로 꼽히...
# 22    최경환 의원(왼쪽)과 안종범 수석(오른쪽)\n기재위, 청문회 실시계획서 채택 불발…...
# 23    김 전 차관 오전 10시, 최씨 오후 2시 출석 예정 삼성그룹의 최씨 일가 특혜 지...
# 24    [<언론사명>]김종인 공격 국민의당 되레↓ 쟁점 법안 촉구 땐 13%대 반등 여론조...
# 25     = 정부가 북한의 gps 전파 교란 도발과 관련해 유엔 안전보장이사회와 관련 국제...
# 26    북한이 연일 미국과 한반도 주변 국가간 갈등을 부각하며 미국의 "쇠퇴"를 주장하고 ...
# 27    임명장 수여식·공식발표 없는 취임식 강행은 경찰청 출범 25년 만에 ][기사보강: ...
# 28    여론조사 전문기관 리얼미터(대표 이택수)의 2016년 1월 4주차(25~29일) 여...
# 29    총선 주요 공약 강봉균 공동선대위원장이 직접  = 새누리당은 28일 공천자대회와 선...
# Name: text, dtype: object

# %%
# grading to vec
# X_grading = grading_df['text']
# X_grading = testX_to_vec(X_grading)

# %%
# predict rank
grading_rank_class = predict_rank(X_grading) # test score 0.87846
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
# predict 결과 확인
grading_rank_class[19]
# Out:
# '매일경제,국민일보,뉴시스,파이낸셜뉴스,MBN,KBS 뉴스,YTN,채널A,연합뉴스TV,TV조선,헤럴드경제,JTBC,연합뉴스,아시아경제,동아일보,노컷뉴스,경향신문,오마이뉴스,서울신문'

# %%
# write csv
output_file = 'submission.txt'
with open(output_file, 'w') as fp:
    for row in grading_rank_class:
        fp.write(row)
        fp.write('\n')

# %% [markdown]
# #### Submission

# %%
ec.upload()
# Out:
# 이전에 업로드 된 파일 삭제 중...
#
# 두 종류의 파일들을 제출해야 합니다.
#  - submission.txt : grading.input.json 에 해당하는 출력값
#  - submission.ipynb 혹은 submission.py : submission.txt를 재현가능한 소스 코드
# 제출할 파일들은 comma (,) 로 나누어 써서 제출할 수 있습니다.
# 제출 예제) submission.ipynb,submission.txt,additional_data.json
#
# > submission.txt,submission.ipynb
# submission.txt 체크 중...
# submission.txt: 2016000 bytes
# submission.ipynb 체크 중...
# submission.ipynb: 5856 bytes
# 업로드 중: submission.txt
# 업로드 중: submission.ipynb
# 업로드가 완료되었습니다.
# submit() 으로 점수를 확인할 수 있습니다.

# %% [markdown]
# 업로드가 완료되면 제출을 시도해봅니다.

# %%
ec.submit()
# Out:
# submission 데이터 개수 = 9000
# 답안 데이터 개수 = 9000
# MRR: 0.18645
# Score: 18 pts.
# 18
# Score: 18
